# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %%
df = pd.read_csv('Copy_of_Global_Superstore2.csv',encoding='ISO-8859-1')
df.head()
# Out:
#    Row ID         Order ID  Order Date   Ship Date     Ship Mode Customer ID  \
# 0   32298   CA-2012-124891  31-07-2012  31-07-2012      Same Day    RH-19495
# 1   26341    IN-2013-77878  05-02-2013  07-02-2013  Second Class    JR-16210
# 2   25330    IN-2013-71249  17-10-2013  18-10-2013   First Class    CR-12730
# 3   13524  ES-2013-1579342  28-01-2013  30-01-2013   First Class    KM-16375
# 4   47221     SG-2013-4320  05-11-2013  06-11-2013      Same Day     RH-9495
#
#       Customer Name      Segment           City            State  ...  \
# 0       Rick Hansen     Consumer  New York City         New York  ...
# 1     Justin Ritter    Corporate     Wollongong  New South Wales  ...
# 2      Craig Reiter     Consumer       Brisbane       Queensland  ...
# 3  Katherine Murray  Home Office         Berlin           Berlin  ...
# 4       Rick Hansen     Consumer          Dakar            Dakar  ...
#
#          Product ID    Category Sub-Category  \
# ...

# %%
df.describe()
# Out:
#             Row ID   Postal Code         Sales      Quantity      Discount  \
# count  51290.00000   9994.000000  51290.000000  51290.000000  51290.000000
# mean   25645.50000  55190.379428    246.490581      3.476545      0.142908
# std    14806.29199  32063.693350    487.565361      2.278766      0.212280
# min        1.00000   1040.000000      0.444000      1.000000      0.000000
# 25%    12823.25000  23223.000000     30.758625      2.000000      0.000000
# 50%    25645.50000  56430.500000     85.053000      3.000000      0.000000
# 75%    38467.75000  90008.000000    251.053200      5.000000      0.200000
# max    51290.00000  99301.000000  22638.480000     14.000000      0.850000
#
#              Profit  Shipping Cost
# count  51290.000000   51290.000000
# mean      28.610982      26.375915
# std      174.340972      57.296804
# min    -6599.978000       0.000000
# 25%        0.000000       2.610000
# 50%        9.240000       7.790000
# 75%       36.810000      24.450000
# ...

# %%
df.shape
# Out:
# (51290, 24)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51290 entries, 0 to 51289
# Data columns (total 24 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Row ID          51290 non-null  int64
#  1   Order ID        51290 non-null  object
#  2   Order Date      51290 non-null  object
#  3   Ship Date       51290 non-null  object
#  4   Ship Mode       51290 non-null  object
#  5   Customer ID     51290 non-null  object
#  6   Customer Name   51290 non-null  object
#  7   Segment         51290 non-null  object
#  8   City            51290 non-null  object
#  9   State           51290 non-null  object
#  10  Country         51290 non-null  object
#  11  Postal Code     9994 non-null   float64
#  12  Market          51290 non-null  object
#  13  Region          51290 non-null  object
#  14  Product ID      51290 non-null  object
#  15  Category        51290 non-null  object
#  16  Sub-Category    51290 non-null  object
# ...

# %%
df['Ship Date'] = pd.to_datetime(df['Ship Date'],format = '%d-%m-%Y')
df['Order Date'] = pd.to_datetime(df['Order Date'],format = '%d-%m-%Y')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51290 entries, 0 to 51289
# Data columns (total 24 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Row ID          51290 non-null  int64
#  1   Order ID        51290 non-null  object
#  2   Order Date      51290 non-null  datetime64[ns]
#  3   Ship Date       51290 non-null  datetime64[ns]
#  4   Ship Mode       51290 non-null  object
#  5   Customer ID     51290 non-null  object
#  6   Customer Name   51290 non-null  object
#  7   Segment         51290 non-null  object
#  8   City            51290 non-null  object
#  9   State           51290 non-null  object
#  10  Country         51290 non-null  object
#  11  Postal Code     9994 non-null   float64
#  12  Market          51290 non-null  object
#  13  Region          51290 non-null  object
#  14  Product ID      51290 non-null  object
#  15  Category        51290 non-null  object
# ...

# %%
df.isnull().sum()
# Out:
# Row ID                0
# Order ID              0
# Order Date            0
# Ship Date             0
# Ship Mode             0
# Customer ID           0
# Customer Name         0
# Segment               0
# City                  0
# State                 0
# Country               0
# Postal Code       41296
# Market                0
# Region                0
# Product ID            0
# Category              0
# Sub-Category          0
# Product Name          0
# Sales                 0
# Quantity              0
# Discount              0
# Profit                0
# Shipping Cost         0
# Order Priority        0
# dtype: int64

# %%
df['Postal Code'] = df['Postal Code'].fillna('NA')

# %%
df.isnull().sum()
# Out:
# Row ID            0
# Order ID          0
# Order Date        0
# Ship Date         0
# Ship Mode         0
# Customer ID       0
# Customer Name     0
# Segment           0
# City              0
# State             0
# Country           0
# Postal Code       0
# Market            0
# Region            0
# Product ID        0
# Category          0
# Sub-Category      0
# Product Name      0
# Sales             0
# Quantity          0
# Discount          0
# Profit            0
# Shipping Cost     0
# Order Priority    0
# dtype: int64

# %% [markdown]
# # Feature Engineering

# %%
df['Profit Margin'] = df['Profit']/df['Sales']
df['Profit Margin'].head()
# Out:
# 0    0.330000
# 1   -0.077847
# 2    0.177766
# 3   -0.033376
# 4    0.109963
# Name: Profit Margin, dtype: float64

# %% [markdown]
# # EDA

# %%
plt.figure(figsize = (30,10))
sns.boxplot(df['Sales'])
plt.title('Sales Box PLot Range')
plt.show()
# Out:
# C:\Users\myaka\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
plt.figure(figsize = (30,10))
sns.lineplot(x = df['Order Date'],y = df['Sales'])
plt.title('Order Date vs Sales')
plt.show()

# %%
plt.figure(figsize = (10,10))
sns.barplot(x = df['Region'],y = df['Shipping Cost'])
plt.title('Region vs Shipping Cost')
plt.show()

# %%
plt.figure(figsize = (30,10))
sns.lineplot(x = df['Order Date'],y = df['Profit'])
plt.title('Order Date vs Profit')
plt.show()

# %%
plt.figure(figsize = (30,10))
sns.barplot(x = df['Sub-Category'], y = df['Profit Margin'])
plt.title('Sub-Category vs Profit Margin')
plt.show()

# %% [markdown]
# # ML

# %%
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_squared_error
from sklearn.preprocessing import LabelEncoder

# %%
le = LabelEncoder()
df['Ship Mode'] = le.fit_transform(df['Ship Mode'])
df['Segment'] = le.fit_transform(df['Segment'])
df['Category'] = le.fit_transform(df['Category'])
df['Sub-Category'] = le.fit_transform(df['Sub-Category'])
df['Order Priority'] = le.fit_transform(df['Order Priority'])
df.head()
# Out:
#    Row ID         Order ID Order Date  Ship Date  Ship Mode Customer ID  \
# 0   32298   CA-2012-124891 2012-07-31 2012-07-31          1    RH-19495
# 1   26341    IN-2013-77878 2013-02-05 2013-02-07          2    JR-16210
# 2   25330    IN-2013-71249 2013-10-17 2013-10-18          0    CR-12730
# 3   13524  ES-2013-1579342 2013-01-28 2013-01-30          0    KM-16375
# 4   47221     SG-2013-4320 2013-11-05 2013-11-06          1     RH-9495
#
#       Customer Name  Segment           City            State  ... Category  \
# 0       Rick Hansen        0  New York City         New York  ...        2
# 1     Justin Ritter        1     Wollongong  New South Wales  ...        0
# 2      Craig Reiter        0       Brisbane       Queensland  ...        2
# 3  Katherine Murray        2         Berlin           Berlin  ...        2
# 4       Rick Hansen        0          Dakar            Dakar  ...        2
#
#   Sub-Category                                       Product Name     Sales  \
# ...

# %%
# Splitting the data into train and test sets
X = df[['Ship Mode','Segment','Category','Sub-Category','Sales','Quantity','Discount','Shipping Cost','Order Priority']]
Y = df['Profit']
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2, random_state=42)

# %%
X.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51290 entries, 0 to 51289
# Data columns (total 9 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Ship Mode       51290 non-null  int64
#  1   Segment         51290 non-null  int32
#  2   Category        51290 non-null  int32
#  3   Sub-Category    51290 non-null  int32
#  4   Sales           51290 non-null  float64
#  5   Quantity        51290 non-null  int64
#  6   Discount        51290 non-null  float64
#  7   Shipping Cost   51290 non-null  float64
#  8   Order Priority  51290 non-null  int32
# dtypes: float64(3), int32(4), int64(2)
# memory usage: 2.7 MB

# %%
model = RandomForestRegressor()

# %%
model.fit(X_train,Y_train)
# Out:
# RandomForestRegressor()

# %%
pred = model.predict(X_test)

# %%
mse = mean_squared_error(Y_test, pred)
print(f'Mean Squared Error: {mse}')
# Out:
# Mean Squared Error: 10801.751400475296

# %%
from sklearn.metrics import r2_score, mean_absolute_error

# Calculate additional metrics
r2 = r2_score(Y_test, pred)
mae = mean_absolute_error(Y_test, pred)
rmse = mean_squared_error(Y_test, pred, squared=False)

print(f'R-squared: {r2}')
print(f'Mean Absolute Error: {mae}')
print(f'Root Mean Squared Error: {rmse}')
# Out:
# R-squared: 0.6375419914946856
# Mean Absolute Error: 36.20313878626205
# Root Mean Squared Error: 103.93147454200434

# %%
pred
# Out:
# array([ -1.869745 ,   3.638434 ,  48.467866 , ...,   3.142216 ,
#         21.93     , 112.6231642])

# %%
plt.figure(figsize=(10, 6))
sns.scatterplot(x=Y_test, y=pred)
plt.xlabel('Actual Profit')
plt.ylabel('Predicted Profit')
plt.title('Actual vs Predicted Profit')
plt.show()

# %% [markdown]
# The provided scatter plot shows the relationship between the actual profit values (on the x-axis) and the predicted profit values (on the y-axis) from the RandomForestRegressor model. Here are some insights based on the scatter plot:
#
# Positive Correlation:
#
# There is a noticeable positive correlation between the actual and predicted profit values. This indicates that as the actual profit increases, the predicted profit also tends to increase, suggesting that the model has learned some relationship between the features and the target variable.
# Clustered Predictions:
#
# Most of the data points are clustered around the line where the actual profit equals the predicted profit (the line y = x). This indicates that for many observations, the predicted profit is close to the actual profit, which is a good sign of model performance.
# Outliers:
#
# There are a few outliers where the predicted profit significantly deviates from the actual profit. These outliers could be due to various reasons, such as:
# The model may not have enough information to accurately predict these specific cases.
# There might be anomalies or noise in the data.
# Certain features that influence profit significantly may be missing from the model.
# Model Performance:
#
# Although there are outliers, the overall trend suggests that the model performs reasonably well for a majority of the data points. To quantitatively evaluate the model performance, we should look at metrics like Mean Squared Error (MSE), Mean Absolute Error (MAE), and R² score, as calculated previously.

# %%
X_test['Predicted Profit'] = pred

# %%
result_df = X_test.copy()
result_df['Actual Profit'] = Y_test

# %%
result_df.to_csv('Pred_Value.csv',index=False)
